# %% [markdown]
# ## 04 - Bulding a pipeline: Input/Output streams
#
# So far, we have only dealt with single subject data. Oftentimes, however, we are dealing with data from multiple subjects and/or multiple runs. Thus, it would be nice to have an automated way to apply the workflow to all the files and store the output in an organized way. Luckily, Nipype comes with functions that handle such input/output stream.
#
# This way, you can build your preprocessing/analysis pipeline for one subject, test it, and then process all subjects in an automated way.

# %% [markdown]
# #### Questions
#
# - How can we apply our worklfow to multiple subjects and runs?
# - How can we stored the processed data in a clear structure?
#
# #### Objective
#
# - Setting up interface nodes handling input and output
# - Learn how to incorporate sub-workflows

# %% [markdown]
# ## Install dependencies and download data

# %%
import os

# !mkdir /data
# !mkdir -p /output/working_dir

# !pip install nilearn
# !pip install nipype

# install fsl
# !sudo apt-get remove -y --purge man-db
# !apt-get update
# !apt-get install neurodebian-archive-keyring
# !add-apt-repository "deb http://neuro.debian.net/debian bionic main contrib non-free"
# !apt-get install fsl-core

fslpath="/usr/share/fsl/5.0" 
os.environ["FSLOUTPUTTYPE"] = "NIFTI"
os.environ["FSLDIR"] = fslpath
os.environ["PATH"] += os.pathsep + os.path.join(fslpath, "bin")
# !. ${FSLDIR}/etc/fslconf/fsl.sh
# !export FSLDIR PATH

os.environ["LD_LIBRARY_PATH"] = os.environ["LD_LIBRARY_PATH"] + os.pathsep + "/usr/lib/fsl/5.0"

# add mni template to fsl dir
# !mkdir /usr/share/fsl/5.0/data/standard
# !gdown --id 1lytUR8CJkcvGIdhndoLjKCUloKl80iCG 
# !unzip /content/mniatlas.zip -d /usr/share/fsl/5.0/data/standard

# install dataset
# !gdown --id 1YP7UtrbsFCCEYxvuY5D3DMiOh7pXyRWJ
# !unzip /content/ds000102.zip -d /data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nilearn
#   Downloading nilearn-0.9.2-py3-none-any.whl (9.6 MB)
#      |████████████████████████████████| 9.6 MB 30.4 MB/s
# Requirement already satisfied: requests>=2 in /usr/local/lib/python3.7/dist-packages (from nilearn) (2.23.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from nilearn) (4.9.1)
# Requirement already satisfied: joblib>=0.15 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.1.0)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.0.2)
# Requirement already satisfied: nibabel>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from nilearn) (3.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.7.3)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from nilearn) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->nilearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->nilearn) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->nilearn) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2->nilearn) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2->nilearn) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2->nilearn) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2->nilearn) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->nilearn) (3.1.0)
# Installing collected packages: nilearn
# Successfully installed nilearn-0.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nipype
#   Downloading nipype-1.8.4-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 30.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from nipype) (21.3)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.7/dist-packages (from nipype) (2.8.2)
# Requirement already satisfied: nibabel>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from nipype) (3.0.2)
# Collecting rdflib>=5.0.0
#   Downloading rdflib-6.2.0-py3-none-any.whl (500 kB)
#      |████████████████████████████████| 500 kB 69.6 MB/s
# Collecting simplejson>=3.8.0
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 76.5 MB/s
# Collecting traits!=5.0,<6.4,>=4.6
#   Downloading traits-6.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.1 MB)
#      |████████████████████████████████| 5.1 MB 63.2 MB/s
# Requirement already satisfied: pydot>=1.2.3 in /usr/local/lib/python3.7/dist-packages (from nipype) (1.3.0)
# Collecting etelemetry>=0.2.0
#   Downloading etelemetry-0.3.0-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from nipype) (1.21.6)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from nipype) (2.6.3)
# Collecting prov>=1.5.2
#   Downloading prov-2.0.0-py3-none-any.whl (421 kB)
#      |████████████████████████████████| 421 kB 89.7 MB/s
# Requirement already satisfied: filelock>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from nipype) (3.8.0)
# Collecting looseversion
#   Downloading looseversion-1.0.1-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from nipype) (1.7.3)
# Requirement already satisfied: click>=6.6.0 in /usr/local/lib/python3.7/dist-packages (from nipype) (7.1.2)
# Collecting ci-info>=0.2
#   Downloading ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from etelemetry>=0.2.0->nipype) (2.23.0)
# Requirement already satisfied: lxml>=3.3.5 in /usr/local/lib/python3.7/dist-packages (from prov>=1.5.2->nipype) (4.9.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot>=1.2.3->nipype) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.2->nipype) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib>=5.0.0->nipype) (4.12.0)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 881 kB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib>=5.0.0->nipype) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=5.0.0->nipype) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib>=5.0.0->nipype) (3.8.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->etelemetry>=0.2.0->nipype) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->etelemetry>=0.2.0->nipype) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->etelemetry>=0.2.0->nipype) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->etelemetry>=0.2.0->nipype) (2022.6.15)
# Installing collected packages: isodate, rdflib, ci-info, traits, simplejson, prov, looseversion, etelemetry, nipype
# Successfully installed ci-info-0.3.0 etelemetry-0.3.0 isodate-0.6.1 looseversion-1.0.1 nipype-1.8.4 prov-2.0.0 rdflib-6.2.0 simplejson-3.17.6 traits-6.3.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   groff-base libnvidia-common-460 libpipeline1
# Use 'sudo apt autoremove' to remove them.
# The following packages will be REMOVED:
#   man-db*
# 0 upgraded, 0 newly installed, 1 to remove and 20 not upgraded.
# After this operation, 2,486 kB disk space will be freed.
# (Reading database ... 155685 files and directories currently installed.)
# Removing man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# (Reading database ... 155454 files and directories currently installed.)
# Purging configuration files for man-db (2.8.3-2ubuntu0.1) ...
#   Removing catpages as well as /var/cache/man hierarchy.
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [91.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,965 kB]
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,099 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,172 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,540 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,396 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,131 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,076 kB]
# Get:22 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.2 kB]
# Fetched 13.8 MB in 3s (4,824 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   groff-base libnvidia-common-460 libpipeline1
# Use 'apt autoremove' to remove them.
# The following NEW packages will be installed:
#   neurodebian-archive-keyring
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 6,762 B of archives.
# After this operation, 23.6 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 neurodebian-archive-keyring all 0.37.6 [6,762 B]
# Fetched 6,762 B in 0s (43.5 kB/s)
# Selecting previously unselected package neurodebian-archive-keyring.
# (Reading database ... 155446 files and directories currently installed.)
# Preparing to unpack .../neurodebian-archive-keyring_0.37.6_all.deb ...
# Unpacking neurodebian-archive-keyring (0.37.6) ...
# Setting up neurodebian-archive-keyring (0.37.6) ...
# Warning: apt-key should not be used in scripts (called from postinst maintainerscript of the package neurodebian-archive-keyring)
# Warning: 'apt-key update' is deprecated and should not be used anymore!
# gpg: key 3B4FE6ACC0B21F32: 3 signatures not checked due to missing keys
# gpg: key 3B4FE6ACC0B21F32: "Ubuntu Archive Automatic Signing Key (2012) <ftpmaster@ubuntu.com>" not changed
# gpg: key D94AA3F0EFE21092: 3 signatures not checked due to missing keys
# gpg: key D94AA3F0EFE21092: "Ubuntu CD Image Automatic Signing Key (2012) <cdimage@ubuntu.com>" not changed
# gpg: key 871920D1991BC93C: 1 signature not checked due to a missing key
# gpg: key 871920D1991BC93C: "Ubuntu Archive Automatic Signing Key (2018) <ftpmaster@ubuntu.com>" not changed
# gpg: Total number processed: 3
# gpg:              unchanged: 3
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Get:2 http://neuro.debian.net/debian bionic InRelease [21.9 kB]
# Hit:3 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Get:10 http://neuro.debian.net/debian bionic/contrib amd64 Packages [16.2 kB]
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:13 http://neuro.debian.net/debian bionic/non-free amd64 Packages [3,826 B]
# Get:14 http://neuro.debian.net/debian bionic/main amd64 Packages [83.2 kB]
# Hit:15 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 125 kB in 2s (81.9 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   groff-base libnvidia-common-460 libpipeline1
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   bc dc fsl-5.0-core javascript-common libgdchart-gd2-noxpm libgiftiio0
#   libjs-excanvas libnewmat10ldbl libnifti2 libpulsedsp libxxf86dga1
#   pulseaudio-utils tcsh wslu x11-utils
# Suggested packages:
#   fsl-feeds fsl-5.0-gpu octave mriconvert | dicomnifti fsl-complete condor
#   | gridengine-client apache2 | lighttpd | httpd avahi-daemon pulseaudio
#   imagemagick mesa-utils
# Recommended packages:
#   fsl-atlases fsl-5.0-eddy-nonfree fslview
# The following NEW packages will be installed:
#   bc dc fsl-5.0-core fsl-core javascript-common libgdchart-gd2-noxpm
#   libgiftiio0 libjs-excanvas libnewmat10ldbl libnifti2 libpulsedsp
#   libxxf86dga1 pulseaudio-utils tcsh wslu x11-utils
# 0 upgraded, 16 newly installed, 0 to remove and 40 not upgraded.
# Need to get 9,402 kB of archives.
# After this operation, 44.0 MB of additional disk space will be used.
# Get:1 http://neuro.debian.net/debian bionic/non-free amd64 fsl-5.0-core amd64 5.0.9-5~nd18.04+1 [8,085 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 bc amd64 1.07.1-2 [86.2 kB]
# Get:4 http://neuro.debian.net/debian bionic/non-free amd64 fsl-core all 5.0.9-5~nd18.04+1 [21.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 dc amd64 1.07.1-2 [48.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 wslu all 2.3.2-0ubuntu2~18.04.3 [46.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tcsh amd64 6.20.00-7 [428 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjs-excanvas all 0.r3-4 [45.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgdchart-gd2-noxpm amd64 0.11.5-10 [38.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libnifti2 amd64 2.0.0-2build1 [102 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgiftiio0 amd64 1.0.9-2 [45.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libnewmat10ldbl amd64 1.10.4-6 [143 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulsedsp amd64 1:11.1-1ubuntu7.11 [31.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 pulseaudio-utils amd64 1:11.1-1ubuntu7.11 [64.3 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Fetched 9,402 kB in 1s (13.8 MB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 155450 files and directories currently installed.)
# Preparing to unpack .../00-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package bc.
# Preparing to unpack .../01-bc_1.07.1-2_amd64.deb ...
# Unpacking bc (1.07.1-2) ...
# Selecting previously unselected package dc.
# Preparing to unpack .../02-dc_1.07.1-2_amd64.deb ...
# Unpacking dc (1.07.1-2) ...
# Selecting previously unselected package wslu.
# Preparing to unpack .../03-wslu_2.3.2-0ubuntu2~18.04.3_all.deb ...
# Unpacking wslu (2.3.2-0ubuntu2~18.04.3) ...
# Selecting previously unselected package tcsh.
# Preparing to unpack .../04-tcsh_6.20.00-7_amd64.deb ...
# Unpacking tcsh (6.20.00-7) ...
# Selecting previously unselected package libjs-excanvas.
# Preparing to unpack .../05-libjs-excanvas_0.r3-4_all.deb ...
# Unpacking libjs-excanvas (0.r3-4) ...
# Selecting previously unselected package libgdchart-gd2-noxpm.
# Preparing to unpack .../06-libgdchart-gd2-noxpm_0.11.5-10_amd64.deb ...
# Unpacking libgdchart-gd2-noxpm (0.11.5-10) ...
# Selecting previously unselected package libnifti2.
# Preparing to unpack .../07-libnifti2_2.0.0-2build1_amd64.deb ...
# Unpacking libnifti2 (2.0.0-2build1) ...
# Selecting previously unselected package libgiftiio0.
# Preparing to unpack .../08-libgiftiio0_1.0.9-2_amd64.deb ...
# Unpacking libgiftiio0 (1.0.9-2) ...
# Selecting previously unselected package libnewmat10ldbl.
# Preparing to unpack .../09-libnewmat10ldbl_1.10.4-6_amd64.deb ...
# Unpacking libnewmat10ldbl (1.10.4-6) ...
# Selecting previously unselected package fsl-5.0-core.
# Preparing to unpack .../10-fsl-5.0-core_5.0.9-5~nd18.04+1_amd64.deb ...
# Unpacking fsl-5.0-core (5.0.9-5~nd18.04+1) ...
# Selecting previously unselected package fsl-core.
# Preparing to unpack .../11-fsl-core_5.0.9-5~nd18.04+1_all.deb ...
# Unpacking fsl-core (5.0.9-5~nd18.04+1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../12-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libpulsedsp:amd64.
# Preparing to unpack .../13-libpulsedsp_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking libpulsedsp:amd64 (1:11.1-1ubuntu7.11) ...
# Selecting previously unselected package pulseaudio-utils.
# Preparing to unpack .../14-pulseaudio-utils_1%3a11.1-1ubuntu7.11_amd64.deb ...
# Unpacking pulseaudio-utils (1:11.1-1ubuntu7.11) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../15-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Setting up libnifti2 (2.0.0-2build1) ...
# Setting up libgiftiio0 (1.0.9-2) ...
# Setting up libpulsedsp:amd64 (1:11.1-1ubuntu7.11) ...
# Setting up pulseaudio-utils (1:11.1-1ubuntu7.11) ...
# Setting up libjs-excanvas (0.r3-4) ...
# Setting up libgdchart-gd2-noxpm (0.11.5-10) ...
# Setting up tcsh (6.20.00-7) ...
# update-alternatives: using /bin/tcsh to provide /bin/csh (csh) in auto mode
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up dc (1.07.1-2) ...
# Setting up javascript-common (11) ...
# Setting up bc (1.07.1-2) ...
# Setting up libnewmat10ldbl (1.10.4-6) ...
# Setting up wslu (2.3.2-0ubuntu2~18.04.3) ...
# update-alternatives: using /usr/bin/wslview to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/wslview to provide /usr/bin/www-browser (www-browser) in auto mode
# Setting up x11-utils (7.7+3build1) ...
# Setting up fsl-5.0-core (5.0.9-5~nd18.04+1) ...
# Setting up fsl-core (5.0.9-5~nd18.04+1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1lytUR8CJkcvGIdhndoLjKCUloKl80iCG
# To: /content/mniatlas.zip
# 100% 55.0M/55.0M [00:00<00:00, 73.9MB/s]
# Archive:  /content/mniatlas.zip
#   inflating: /usr/share/fsl/5.0/data/standard/avg152T1_brain.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/avg152T1.nii.gz
#    creating: /usr/share/fsl/5.0/data/standard/bianca/
#   inflating: /usr/share/fsl/5.0/data/standard/bianca/HarvardOxford-1mm-latvent-dilated.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/bianca/bianca_exclusion_mask.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/FMRIB58_FA_1mm.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/FMRIB58_FA-skeleton_1mm.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/Fornix_FMRIB_FA1mm.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/LowerCingulum_1mm.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_0.5mm.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_1mm_brain_mask_dil.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_1mm_brain_mask.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_1mm_brain.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_1mm_first_brain_mask.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_1mm_Hipp_mask_dil8.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_1mm.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_b0.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_brain_mask_deweight_eyes.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_brain_mask_dil.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_brain_mask_dil1.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_brain_mask.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_brain.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_edges.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_eye_mask.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_LR-masked.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_skull.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_strucseg_periph.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_strucseg.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm_VentricleMask.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152_T1_2mm.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152lin_T1_1mm_brain.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152lin_T1_1mm_subbr_mask.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152lin_T1_1mm.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152lin_T1_2mm_brain_mask.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152lin_T1_2mm_brain.nii.gz
#   inflating: /usr/share/fsl/5.0/data/standard/MNI152lin_T1_2mm.nii.gz
#    creating: /usr/share/fsl/5.0/data/standard/tissuepriors/
#   inflating: /usr/share/fsl/5.0/data/standard/tissuepriors/avg152T1_csf.img
#   inflating: /usr/share/fsl/5.0/data/standard/tissuepriors/avg152T1_white.hdr
#   inflating: /usr/share/fsl/5.0/data/standard/tissuepriors/avg152T1_gray.hdr
#   inflating: /usr/share/fsl/5.0/data/standard/tissuepriors/avg152T1_brain.img
#   inflating: /usr/share/fsl/5.0/data/standard/tissuepriors/avg152T1_brain.hdr
#   inflating: /usr/share/fsl/5.0/data/standard/tissuepriors/avg152T1_white.img
#   inflating: /usr/share/fsl/5.0/data/standard/tissuepriors/avg152T1_csf.hdr
#   inflating: /usr/share/fsl/5.0/data/standard/tissuepriors/avg152T1_gray.img
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1YP7UtrbsFCCEYxvuY5D3DMiOh7pXyRWJ
# To: /content/ds000102.zip
# 100% 204M/204M [00:01<00:00, 180MB/s]
# Archive:  /content/ds000102.zip
#    creating: /data/ds000102/
#   inflating: /data/ds000102/task-flanker_bold.json
#   inflating: /data/ds000102/.DS_Store
#   inflating: /data/ds000102/CHANGES
#    creating: /data/ds000102/sub-01/
#   inflating: /data/ds000102/README
#   inflating: /data/ds000102/dataset_description.json
#   inflating: /data/ds000102/T1w.json
#   inflating: /data/ds000102/participants.tsv
#    creating: /data/ds000102/sub-02/
#    creating: /data/ds000102/sub-03/
#   inflating: /data/ds000102/sub-01/.DS_Store
#    creating: /data/ds000102/sub-01/anat/
#    creating: /data/ds000102/sub-01/func/
#    creating: /data/ds000102/sub-02/anat/
#    creating: /data/ds000102/sub-02/func/
#    creating: /data/ds000102/sub-03/anat/
#    creating: /data/ds000102/sub-03/func/
#   inflating: /data/ds000102/sub-01/anat/sub-01_T1w.nii.gz
#   inflating: /data/ds000102/sub-01/func/sub-01_task-flanker_run-1_bold.nii.gz
#   inflating: /data/ds000102/sub-01/func/sub-01_task-flanker_run-2_bold.nii.gz
#   inflating: /data/ds000102/sub-01/func/sub-01_task-flanker_run-2_events.tsv
#   inflating: /data/ds000102/sub-01/func/sub-01_task-flanker_run-1_events.tsv
#   inflating: /data/ds000102/sub-02/anat/sub-02_T1w.nii.gz
#   inflating: /data/ds000102/sub-02/func/sub-02_task-flanker_run-1_events.tsv
#   inflating: /data/ds000102/sub-02/func/sub-02_task-flanker_run-2_bold.nii.gz
#   inflating: /data/ds000102/sub-02/func/sub-02_task-flanker_run-2_events.tsv
#   inflating: /data/ds000102/sub-02/func/sub-02_task-flanker_run-1_bold.nii.gz
#   inflating: /data/ds000102/sub-03/anat/sub-03_T1w.nii.gz
#   inflating: /data/ds000102/sub-03/func/sub-03_task-flanker_run-1_events.tsv
#   inflating: /data/ds000102/sub-03/func/sub-03_task-flanker_run-1_bold.nii.gz
#   inflating: /data/ds000102/sub-03/func/sub-03_task-flanker_run-2_bold.nii.gz
#   inflating: /data/ds000102/sub-03/func/sub-03_task-flanker_run-2_events.tsv

# %%
data_dir = "/data/ds000102"
output_dir = "/output"

# %% [markdown]
# ## Setup workflows

# %% [markdown]
# After everything has been installed, let's create a new (main) worklow:

# %%
from nipype import Workflow, Node

wf = Workflow(name = "test_workflow",
               base_dir = "/output/working_dir")

# %% [markdown]
# In our sample dataset we have three subject. Let's create a list of their IDs:

# %%
subject_list = ["sub-01", "sub-02", "sub-03"]

# %% [markdown]
# ### Input/Output stream

# %% [markdown]
# For the input stream we will use the Nipype classes [```IdentityInterface```](https://nipype.readthedocs.io/en/0.12.1/interfaces/generated/nipype.interfaces.utility.html#index-3) and [```SelectFiles```](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.io.html#selectfiles). For the output we will use the so called [```DataSink```](https://nipype.readthedocs.io/en/latest/api/generated/nipype.interfaces.io.html#datasink):

# %%
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.interfaces.utility import IdentityInterface

# %% [markdown]
# With ```IdentityInterface``` we can iterate over a given list. In our case, this will be the subject list we have defined earlier. This will allow us to apply our workflow to all three subjects. Specifically, we set the ```fields``` parameter to ```"subject_id"``` (note that Nipype expects a list as input). The exact name here is arbitrary (you could also name it ```"sub"```). The important thing is that it matches the first element of the touple we provide to the ```iterables``` argument.
#
# With this ```iterables``` argument, we basically tell Nipype "hey please iterate over every ```"subject_id"``` (or ```"sub"``` or whatever you may call it) you can find in ```subject_list```"
#
# (Note that we place the interface within a Node so that we can include it in our workflow)

# %%
# iteration over all participants
infosource = Node(IdentityInterface(fields = ["subject_id"]),                   # fields parameter needs to be a list, hence the brackets
                  name = "infosource")
                  
infosource.iterables = [("subject_id", subject_list)]

# %% [markdown]
# ```SelectFiles``` can be used to access the files of the respective subjects. Here, we have to specify a template, that matches the paths of the files we want to analyze - in our case, we provide the locations of both the functional and anatomical image. Note that ```subject_id``` is in curly brackets (this may be familar to you from Python's f strings) - this way, Nipype can iterative over the subject list and update the path in each iteration (importantly, the identifier string needs to match the one you passed to the ```fields``` parameter of the ```IdentitiyInterface```)

# %%
templates = {"anat": "{subject_id}/anat/{subject_id}_T1w.nii.gz",
             "func": "{subject_id}/func/{subject_id}_task-flanker_run-1_bold.nii.gz"}

selectfiles = Node(SelectFiles(templates, base_directory = data_dir, sort_filelist=True),
                   name = "selectfiles")

# %% [markdown]
# To organize the output of our workflow, we will use Nipype's ```DataSink```. This is rather simple, we specify the the directory where we want to store the output folder (the name of the output folder is defined by the ```container``` parameter)

# %%
output_dir = "/output"

# Datasink/Output
datasink = Node(DataSink(base_directory=output_dir),
                name="datasink")

# %% [markdown]
# ### Including a sub-workflow (or: "nested workflows")

# %% [markdown]
# Now that we have specified the input and output stream, we can define nodes to segment the participants' brains - just as we did last week. This time, however, we will create a second workflow (basically a **"workflow in a workflow"**).
#
# The main reason for this is clarity and comprehensibility: A complete preprocessing pipeline often includes a lot of different steps (or, in the world of Nipype: *Nodes*). Importantly, some steps can be logically grouped together (e.g., before segmenting the brain, one performs brain extraction in most cases). Thus, it makes sense for us to maintain this logic in our workflow. See [here](https://notebook.community/kdestasio/online_brain_intensive/nipype_tutorial/notebooks/basic_workflow) for a more detailed overview on workflows and specifically on nested workflows.

# %% [markdown]
# Let's create our first sub-workflow!

# %%
segment_wf = Workflow(name = "segment_wf",
                      base_dir = "/output/working_dir")

# %% [markdown]
# As we did last week, we have to setup Nodes for the brain extraction and smoothing. Note that other than in last week's notebook, we don't specify an input file for the brain extraction node - this will be handled by ```IdentityInterface```and ```SelectFiles```, respectively.

# %%
from nipype.interfaces.fsl import BET, FAST
from nipype import Node, Workflow

# Skullstrip Node
strip_skull = Node(BET(mask=True),
                   name = "strip_skull")

# Segmentation Node
segment     = Node(FAST(),
                   name = "segment")

# %% [markdown]
# Now, let's connect the nodes of our sub-workflow. The only thing we need to do is specifying the brain extraction output as the input for the segmentation node (we don't need to care about input and output as this will be handled by our main workflow).

# %%
segment_wf.connect([ (strip_skull, segment, [("out_file", "in_files")]) ])

# %% [markdown]
# Next, let's tie all nodes together!
# Unsurpringsingly, the first connection of our workflows handles the input. Specifically, we pass ```"subject_id"``` from ```IdentitiyInterface``` (remember the ```fields``` argument) to the ```SelectFiles``` node (now ```Selectfiles``` knows how to fill the template we have provided).
#
# Afer speciying the input, it's time to include our segmentation sub-worfklow. To connect it to our main workflow, we need to change up the syntax a little bit. Specifically we need to include the sub-workflow's name in the call of the ```connect``` method. Thus,
# ```
# (selectfiles, strip_skull, [("anat", "in_file")])
# ```
# becomes
# ```
# (selectfiles, segment_wf,  [("anat", "strip_skull.in_file")] )
# ```
#
# Let's put everything together!

# %%
wf.connect([  (infosource, selectfiles,  [("subject_id", "subject_id")] ),
              (selectfiles, segment_wf,  [("anat", "strip_skull.in_file")] ),

              (segment_wf, datasink,     [("strip_skull.out_file", "datasink.@bet")] ),
              (segment_wf, datasink,     [("strip_skull.mask_file", "datasink.@bet_mask")] ),
              (segment_wf, datasink,     [("segment.partial_volume_files", "datasink.@segment")] )
            ]
           )

# %%
wf.write_graph("workflow_graph.dot")
from IPython.display import Image
Image(filename="/output/working_dir/test_workflow/workflow_graph.png")
# Out:
# 220909-12:47:22,321 nipype.workflow INFO:
# 	 Generated workflow graph: /output/working_dir/test_workflow/workflow_graph.png (graph2use=hierarchical, simple_form=True).
# INFO:nipype.workflow:Generated workflow graph: /output/working_dir/test_workflow/workflow_graph.png (graph2use=hierarchical, simple_form=True).

# %% [markdown]
# As you can see, we have succesfully included a sub-workflow in our routine. In fact, Nipype comes with a few already pre-defined workflows - check them out [here](https://nipype.readthedocs.io/en/1.1.7/interfaces/generated/workflows.fmri.html).

# %%
wf.run('MultiProc', plugin_args={'n_procs': 2})
# Out:
# 220909-12:47:29,396 nipype.workflow INFO:
# 	 Workflow test_workflow settings: ['check', 'execution', 'logging', 'monitoring']
# INFO:nipype.workflow:Workflow test_workflow settings: ['check', 'execution', 'logging', 'monitoring']
# 220909-12:47:29,426 nipype.workflow INFO:
# 	 Running in parallel.
# INFO:nipype.workflow:Running in parallel.
# 220909-12:47:29,457 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# INFO:nipype.workflow:[MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# 220909-12:47:29,570 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.selectfiles" in "/output/working_dir/test_workflow/_subject_id_sub-01/selectfiles".
# 220909-12:47:29,580 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.selectfiles" in "/output/working_dir/test_workflow/_subject_id_sub-02/selectfiles".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.selectfiles" in "/output/working_dir/test_workflow/_subject_id_sub-02/selectfiles".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.selectfiles" in "/output/working_dir/test_workflow/_subject_id_sub-01/selectfiles".
# 220909-12:47:29,597 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220909-12:47:29,598 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# INFO:nipype.workflow:[Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# INFO:nipype.workflow:[Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220909-12:47:29,620 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.001035s.
# INFO:nipype.workflow:[Node] Finished "selectfiles", elapsed time 0.001035s.
# 220909-12:47:29,616 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.001098s.
# INFO:nipype.workflow:[Node] Finished "selectfiles", elapsed time 0.001098s.
# 220909-12:47:31,458 nipype.workflow INFO:
# 	 [Job 0] Completed (test_workflow.selectfiles).
# INFO:nipype.workflow:[Job 0] Completed (test_workflow.selectfiles).
# 220909-12:47:31,463 nipype.workflow INFO:
# 	 [Job 1] Completed (test_workflow.selectfiles).
# INFO:nipype.workflow:[Job 1] Completed (test_workflow.selectfiles).
# 220909-12:47:31,467 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# INFO:nipype.workflow:[MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# 220909-12:47:31,531 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.selectfiles" in "/output/working_dir/test_workflow/_subject_id_sub-03/selectfiles".
# 220909-12:47:31,532 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.segment_wf.strip_skull" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-01/strip_skull".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.selectfiles" in "/output/working_dir/test_workflow/_subject_id_sub-03/selectfiles".
# 220909-12:47:31,540 nipype.workflow INFO:
# 	 [Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.segment_wf.strip_skull" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-01/strip_skull".
# INFO:nipype.workflow:[Node] Executing "selectfiles" <nipype.interfaces.io.SelectFiles>
# 220909-12:47:31,550 nipype.workflow INFO:
# 	 [Node] Finished "selectfiles", elapsed time 0.000694s.
# 220909-12:47:31,556 nipype.workflow INFO:
# 	 [Node] Executing "strip_skull" <nipype.interfaces.fsl.preprocess.BET>
# INFO:nipype.workflow:[Node] Finished "selectfiles", elapsed time 0.000694s.
# INFO:nipype.workflow:[Node] Executing "strip_skull" <nipype.interfaces.fsl.preprocess.BET>
# 220909-12:47:33,443 nipype.workflow INFO:
# 	 [Node] Finished "strip_skull", elapsed time 1.880589s.
# INFO:nipype.workflow:[Node] Finished "strip_skull", elapsed time 1.880589s.
# 220909-12:47:33,461 nipype.workflow INFO:
# 	 [Job 2] Completed (test_workflow.selectfiles).
# INFO:nipype.workflow:[Job 2] Completed (test_workflow.selectfiles).
# 220909-12:47:33,467 nipype.workflow INFO:
# 	 [Job 3] Completed (test_workflow.segment_wf.strip_skull).
# INFO:nipype.workflow:[Job 3] Completed (test_workflow.segment_wf.strip_skull).
# 220909-12:47:33,471 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# INFO:nipype.workflow:[MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# 220909-12:47:33,525 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.segment_wf.strip_skull" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-02/strip_skull".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.segment_wf.strip_skull" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-02/strip_skull".
# 220909-12:47:33,531 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.segment_wf.strip_skull" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-03/strip_skull".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.segment_wf.strip_skull" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-03/strip_skull".
# 220909-12:47:33,541 nipype.workflow INFO:
# 	 [Node] Executing "strip_skull" <nipype.interfaces.fsl.preprocess.BET>
# INFO:nipype.workflow:[Node] Executing "strip_skull" <nipype.interfaces.fsl.preprocess.BET>
# 220909-12:47:33,543 nipype.workflow INFO:
# 	 [Node] Executing "strip_skull" <nipype.interfaces.fsl.preprocess.BET>
# INFO:nipype.workflow:[Node] Executing "strip_skull" <nipype.interfaces.fsl.preprocess.BET>
# 220909-12:47:35,463 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 11.01/11.41, Free processors: 0/2.
#                      Currently running:
#                        * test_workflow.segment_wf.strip_skull
#                        * test_workflow.segment_wf.strip_skull
# INFO:nipype.workflow:[MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 11.01/11.41, Free processors: 0/2.
#                      Currently running:
#                        * test_workflow.segment_wf.strip_skull
#                        * test_workflow.segment_wf.strip_skull
# 220909-12:47:36,513 nipype.workflow INFO:
# 	 [Node] Finished "strip_skull", elapsed time 2.965804s.
# INFO:nipype.workflow:[Node] Finished "strip_skull", elapsed time 2.965804s.
# 220909-12:47:36,546 nipype.workflow INFO:
# 	 [Node] Finished "strip_skull", elapsed time 2.980137s.
# INFO:nipype.workflow:[Node] Finished "strip_skull", elapsed time 2.980137s.
# 220909-12:47:37,465 nipype.workflow INFO:
# 	 [Job 4] Completed (test_workflow.segment_wf.strip_skull).
# INFO:nipype.workflow:[Job 4] Completed (test_workflow.segment_wf.strip_skull).
# 220909-12:47:37,468 nipype.workflow INFO:
# 	 [Job 5] Completed (test_workflow.segment_wf.strip_skull).
# INFO:nipype.workflow:[Job 5] Completed (test_workflow.segment_wf.strip_skull).
# 220909-12:47:37,472 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# INFO:nipype.workflow:[MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# 220909-12:47:37,530 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.segment_wf.segment" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-01/segment".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.segment_wf.segment" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-01/segment".
# 220909-12:47:37,531 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.segment_wf.segment" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-02/segment".
# 220909-12:47:37,538 nipype.workflow INFO:
# 	 [Node] Executing "segment" <nipype.interfaces.fsl.preprocess.FAST>
# INFO:nipype.workflow:[Node] Executing "segment" <nipype.interfaces.fsl.preprocess.FAST>
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.segment_wf.segment" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-02/segment".
# 220909-12:47:37,555 nipype.workflow INFO:
# 	 [Node] Executing "segment" <nipype.interfaces.fsl.preprocess.FAST>
# INFO:nipype.workflow:[Node] Executing "segment" <nipype.interfaces.fsl.preprocess.FAST>
# 220909-12:47:39,467 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 11.01/11.41, Free processors: 0/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
#                        * test_workflow.segment_wf.segment
# INFO:nipype.workflow:[MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 11.01/11.41, Free processors: 0/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
#                        * test_workflow.segment_wf.segment
# 220909-12:52:36,126 nipype.workflow INFO:
# 	 [Node] Finished "segment", elapsed time 298.561891s.
# INFO:nipype.workflow:[Node] Finished "segment", elapsed time 298.561891s.
# 220909-12:52:37,817 nipype.workflow INFO:
# 	 [Job 7] Completed (test_workflow.segment_wf.segment).
# INFO:nipype.workflow:[Job 7] Completed (test_workflow.segment_wf.segment).
# 220909-12:52:37,825 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 11.21/11.41, Free processors: 1/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
# INFO:nipype.workflow:[MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 11.21/11.41, Free processors: 1/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
# 220909-12:52:37,901 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.segment_wf.segment" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-03/segment".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.segment_wf.segment" in "/output/working_dir/test_workflow/segment_wf/_subject_id_sub-03/segment".
# 220909-12:52:37,918 nipype.workflow INFO:
# 	 [Node] Executing "segment" <nipype.interfaces.fsl.preprocess.FAST>
# INFO:nipype.workflow:[Node] Executing "segment" <nipype.interfaces.fsl.preprocess.FAST>
# 220909-12:52:39,681 nipype.workflow INFO:
# 	 [Node] Finished "segment", elapsed time 302.133791s.
# INFO:nipype.workflow:[Node] Finished "segment", elapsed time 302.133791s.
# 220909-12:52:39,819 nipype.workflow INFO:
# 	 [Job 6] Completed (test_workflow.segment_wf.segment).
# INFO:nipype.workflow:[Job 6] Completed (test_workflow.segment_wf.segment).
# 220909-12:52:39,831 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 11.21/11.41, Free processors: 1/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
# INFO:nipype.workflow:[MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 11.21/11.41, Free processors: 1/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
# 220909-12:52:39,905 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.datasink" in "/output/working_dir/test_workflow/_subject_id_sub-01/datasink".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.datasink" in "/output/working_dir/test_workflow/_subject_id_sub-01/datasink".
# 220909-12:52:39,926 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# INFO:nipype.workflow:[Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220909-12:52:39,942 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001366s.
# INFO:nipype.workflow:[Node] Finished "datasink", elapsed time 0.001366s.
# 220909-12:52:41,821 nipype.workflow INFO:
# 	 [Job 9] Completed (test_workflow.datasink).
# INFO:nipype.workflow:[Job 9] Completed (test_workflow.datasink).
# 220909-12:52:41,828 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 11.21/11.41, Free processors: 1/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
# INFO:nipype.workflow:[MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 11.21/11.41, Free processors: 1/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
# 220909-12:52:41,902 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.datasink" in "/output/working_dir/test_workflow/_subject_id_sub-02/datasink".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.datasink" in "/output/working_dir/test_workflow/_subject_id_sub-02/datasink".
# 220909-12:52:41,917 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# INFO:nipype.workflow:[Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220909-12:52:41,929 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.001356s.
# INFO:nipype.workflow:[Node] Finished "datasink", elapsed time 0.001356s.
# 220909-12:52:43,823 nipype.workflow INFO:
# 	 [Job 10] Completed (test_workflow.datasink).
# INFO:nipype.workflow:[Job 10] Completed (test_workflow.datasink).
# 220909-12:52:43,837 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 11.21/11.41, Free processors: 1/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
# INFO:nipype.workflow:[MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 11.21/11.41, Free processors: 1/2.
#                      Currently running:
#                        * test_workflow.segment_wf.segment
# 220909-12:56:08,856 nipype.workflow INFO:
# 	 [Node] Finished "segment", elapsed time 210.923789s.
# INFO:nipype.workflow:[Node] Finished "segment", elapsed time 210.923789s.
# 220909-12:56:10,17 nipype.workflow INFO:
# 	 [Job 8] Completed (test_workflow.segment_wf.segment).
# INFO:nipype.workflow:[Job 8] Completed (test_workflow.segment_wf.segment).
# 220909-12:56:10,21 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# INFO:nipype.workflow:[MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# 220909-12:56:10,68 nipype.workflow INFO:
# 	 [Node] Setting-up "test_workflow.datasink" in "/output/working_dir/test_workflow/_subject_id_sub-03/datasink".
# INFO:nipype.workflow:[Node] Setting-up "test_workflow.datasink" in "/output/working_dir/test_workflow/_subject_id_sub-03/datasink".
# 220909-12:56:10,79 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# INFO:nipype.workflow:[Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 220909-12:56:10,87 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.00154s.
# INFO:nipype.workflow:[Node] Finished "datasink", elapsed time 0.00154s.
# 220909-12:56:12,19 nipype.workflow INFO:
# 	 [Job 11] Completed (test_workflow.datasink).
# INFO:nipype.workflow:[Job 11] Completed (test_workflow.datasink).
# 220909-12:56:12,24 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.
# INFO:nipype.workflow:[MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 11.41/11.41, Free processors: 2/2.

# %% [markdown]
# Let's check our results. We will every subject's extracted brain, overlayed with contours of their grey matter:

# %%
from nilearn import plotting
import matplotlib.pyplot as plt

for subject in subject_list:
  
  exracted_brain = f"/output/datasink/_subject_id_{subject}/{subject}_T1w_brain.nii"
  grey_matter = f"/output/datasink/_subject_id_{subject}/{subject}_T1w_brain_pve_1.nii"
  
  fig = plt.figure(figsize=(10,5))

  disp = plotting.plot_anat(exracted_brain, title = subject, figure=fig)
  disp.add_contours(grey_matter, levels=[0.5])

# %% [markdown]
# ## Exercise
#
# In this notebook we learned how to apply Nipype workflows to multiple subjects and/or runs. Also, we learned how to construct workflows inside workflows. In this exercise your task is to include the two nodes you created in the last exercise (i.e., Realignment and Slicetiming correction). This will get us closer to our final pipeline! The exact steps are:
#
# - Define main worfklow (see above)
# - Setup Realignment and slicetime correction nodes (see last week's exercise)
# - Connect all nodes

# %%
# we delete the main workflow object so that you can form new connections
del wf

# %% [markdown]
# ## Resources
#
# [Nipype Tutorial: Data Input](https://miykael.github.io/nipype_tutorial/notebooks/basic_data_input.html)
#
# [Nipype Tutorial: Data Output](https://miykael.github.io/nipype_tutorial/notebooks/basic_data_output.html)
